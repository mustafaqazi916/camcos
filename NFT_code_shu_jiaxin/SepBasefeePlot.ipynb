# %% [markdown]
# ## Sep Base Fee Plot

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df_sep = pd.read_csv('Sep_basefee.csv')
df_sep.head()
# Out:
#    block_number  block_date  block_hour      time    base_fee
# 0      13136427  2021-09-01           0  00:00:12  124.202762
# 1      13136428  2021-09-01           0  00:00:40  139.713515
# 2      13136429  2021-09-01           0  00:00:44  130.857527
# 3      13136430  2021-09-01           0  00:00:46  115.769453
# 4      13136431  2021-09-01           0  00:00:48  108.952305

# %%
# 09/01 -- {21:1} 
df[(df.block_date==1) & (df.block_hour==21)].base_fee.plot();

# %%
# 09/02 -- {22:1} 
df[(df.block_date==2) & (df.block_hour==22)].base_fee.plot();

# %%
# 09/03 -- {6,7,10,11,14,22} 
df[(df.block_date==3) & (df.block_hour==6)].base_fee.plot()
df[(df.block_date==3) & (df.block_hour==7)].base_fee.plot()
df[(df.block_date==3) & (df.block_hour==10)].base_fee.plot()
df[(df.block_date==3) & (df.block_hour==11)].base_fee.plot()
df[(df.block_date==3) & (df.block_hour==14)].base_fee.plot()
df[(df.block_date==3) & (df.block_hour==22)].base_fee.plot();

# %%
# 09/04 -- {16,17} 
df[(df.block_date==4) & (df.block_hour==16)].base_fee.plot()
df[(df.block_date==4) & (df.block_hour==17)].base_fee.plot();

# %%
# 09/05 -- {16,17} 
df[(df.block_date==5) & (df.block_hour==16)].base_fee.plot()
df[(df.block_date==5) & (df.block_hour==17)].base_fee.plot();

# %%
# 09/06 -- {2,17,20} 
df[(df.block_date==6) & (df.block_hour==2)].base_fee.plot()
df[(df.block_date==6) & (df.block_hour==17)].base_fee.plot()
df[(df.block_date==6) & (df.block_hour==20)].base_fee.plot();

# %%
# 09/07 -- {19} 
df[(df.block_date==7) & (df.block_hour==19)].base_fee.plot();

# %%
# 09/08 -- {1,2} 
df[(df.block_date==8) & (df.block_hour==1)].base_fee.plot()
df[(df.block_date==8) & (df.block_hour==2)].base_fee.plot();

# %%
# 09/09 -- {} 
df[(df.block_date==9) & (df.block_hour==2)].base_fee.plot();

# %%
# 09/10 -- {} 
df[(df.block_date==10) & (df.block_hour==21)].base_fee.plot();

# %%
# 09/12 -- {} 
df[(df.block_date==12) & (df.block_hour==19)].base_fee.plot()
df[(df.block_date==12) & (df.block_hour==20)].base_fee.plot();

# %%
# 09/13 -- {} 
df[(df.block_date==13) & (df.block_hour==13)].base_fee.plot()
df[(df.block_date==13) & (df.block_hour==14)].base_fee.plot();

# %%
# 09/14 -- {} 
df[(df.block_date==14) & (df.block_hour==16)].base_fee.plot();

# %%
# 09/15 -- {} 
df[(df.block_date==15) & (df.block_hour==18)].base_fee.plot();

# %%
# 09/16 -- {} 
df[(df.block_date==16) & (df.block_hour==19)].base_fee.plot();

# %%
# 09/17 -- {} 
df[(df.block_date==17) & (df.block_hour==8)].base_fee.plot()
df[(df.block_date==17) & (df.block_hour==15)].base_fee.plot()
df[(df.block_date==17) & (df.block_hour==16)].base_fee.plot();

# %%
# 09/19 -- {} 
df[(df.block_date==19) & (df.block_hour==20)].base_fee.plot();

# %%
# 09/20 -- {} 
df[(df.block_date==20) & (df.block_hour==16)].base_fee.plot()
df[(df.block_date==20) & (df.block_hour==21)].base_fee.plot();

# %%
# 09/21 -- {} 
df[(df.block_date==21) & (df.block_hour==0)].base_fee.plot()
df[(df.block_date==21) & (df.block_hour==17)].base_fee.plot()
df[(df.block_date==21) & (df.block_hour==19)].base_fee.plot()
df[(df.block_date==21) & (df.block_hour==20)].base_fee.plot()
df[(df.block_date==21) & (df.block_hour==21)].base_fee.plot();

# %%
# 09/22 -- {} 
df[(df.block_date==22) & (df.block_hour==22)].base_fee.plot()
df[(df.block_date==22) & (df.block_hour==23)].base_fee.plot()
# Out:
# <AxesSubplot:>

# %%
# 09/23 -- {} 
df[(df.block_date==23) & (df.block_hour==0)].base_fee.plot()
df[(df.block_date==23) & (df.block_hour==16)].base_fee.plot();

# %%
# 09/24 -- {} 
df[(df.block_date==24) & (df.block_hour==16)].base_fee.plot();

# %%
# 09/25 -- {} 
df[(df.block_date==25) & (df.block_hour==18)].base_fee.plot()
df[(df.block_date==25) & (df.block_hour==19)].base_fee.plot();

# %%
# 09/26 -- {} 
df[(df.block_date==26) & (df.block_hour==5)].base_fee.plot();

# %%
# 09/27 -- {} 
df[(df.block_date==27) & (df.block_hour==19)].base_fee.plot()
df[(df.block_date==27) & (df.block_hour==21)].base_fee.plot();

# %%
# 09/28 -- {} 
df[(df.block_date==28) & (df.block_hour==16)].base_fee.plot()
df[(df.block_date==28) & (df.block_hour==17)].base_fee.plot()
df[(df.block_date==28) & (df.block_hour==18)].base_fee.plot();
# Out:
# <AxesSubplot:>

# %%
# 09/29 -- {} 
df[(df.block_date==29) & (df.block_hour==16)].base_fee.plot();

# %%
# 09/30 -- {} 
df[(df.block_date==30) & (df.block_hour==2)].base_fee.plot()
df[(df.block_date==30) & (df.block_hour==3)].base_fee.plot()
df[(df.block_date==30) & (df.block_hour==5)].base_fee.plot()
df[(df.block_date==30) & (df.block_hour==20)].base_fee.plot()
df[(df.block_date==30) & (df.block_hour==21)].base_fee.plot()
df[(df.block_date==30) & (df.block_hour==23)].base_fee.plot();
